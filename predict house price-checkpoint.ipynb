# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
##load dataset
df=pd.read_csv('house-price.csv')
df.head()
# Out:
#    area    price
# 0   400  2000000
# 1   500  2500000
# 2   600  3000000
# 3   700  3500000
# 4   800  4000000

# %%
df.corr()
# Out:
#        area  price
# area    1.0    1.0
# price   1.0    1.0

# %%
##visulization
plt.scatter(df['area'],df['price'])
plt.xlabel('area')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
import seaborn as sns
sns.pairplot(df)

# %%
##split data
from sklearn.model_selection import train_test_split
x=df[['area']]
y=df[['price']]

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#    area
# 5   900
# 0   400
# 7  1100
# 2   600
# 9  1300
# 4   800
# 3   700
# 6  1000

# %%
x_test
# Out:
#    area
# 8  1200
# 1   500

# %%
##standardization means feautures ko same scale par lana where 
##mean is 0 and standardization is1
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)

# %%
x_test=scaler.transform(x_test)

# %%
x_test
# Out:
# array([[ 1.29986737],
#        [-1.29986737]])

# %%
##train model
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
##prediction
y_pred=model.predict(x_test)

# %%
##model line visulization
plt.scatter(x,y)
plt.plot(x,model.predict(x),color='red')
# Out:
# C:\Users\avnin\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %%
model.predict(scaler.transform([[200]]))
# Out:
# C:\Users\avnin\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[1000000.]])

# %%
##new data salary experinces
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
##load dataset
df=pd.read_csv('salary_data.csv')

# %%
df.head()
# Out:
#    experinces  salary
# 0           0   15000
# 1           1   18000
# 2           2   22000
# 3           3   26000
# 4           4   30000

# %%
##DATA visulation
plt.scatter(df['experinces'],df['salary'])
plt.xlabel("experinces")
plt.ylabel("salary")
# Out:
# Text(0, 0.5, 'salary')

# %%
sns.pairplot(df)

# %%
##split dataset
from sklearn.model_selection import train_test_split
x=df[['experinces']]
y=df[['salary']]

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#    experinces
# 5           5
# 0           0
# 7           7
# 2           2
# 9           9
# 4           4
# 3           3
# 6           6

# %%
x_test
# Out:
#    experinces
# 8           8
# 1           1

# %%
##standardization
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)
# Out:
# C:\Users\avnin\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(

# %%
x_train
# Out:
# array([[ 0.18569534],
#        [-1.67125804],
#        [ 0.92847669],
#        [-0.92847669],
#        [ 1.67125804],
#        [-0.18569534],
#        [-0.55708601],
#        [ 0.55708601]])

# %%
##train 
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
##predict
y_predict=model.predict(x_test)

# %%
##
plt.scatter(x,y)
plt.plot(x,model.predict(x),color='green')
plt.xlabel('experinces')
plt.ylabel('salary')
# Out:
# C:\Users\avnin\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# Text(0, 0.5, 'salary')

# %%
model.predict(scaler.transform([[0]]))
# Out:
# array([[75000.]])
